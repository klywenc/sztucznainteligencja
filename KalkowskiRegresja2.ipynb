# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(tf.__version__)
# Out:
# 2.18.0

# %%
training_data = np.load('TF_dataset.npz')
input_size = 2
output_size = 1

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(5, activation='sigmoid'),
    tf.keras.layers.Dense(5, activation='sigmoid'),
    tf.keras.layers.Dense(output_size)
])
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(training_data['inputs'], training_data['targets'], epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6996.3955
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3230.1926
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2028.3954
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1557.6653
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1383.5442
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1112.2169
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1234.2573
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1105.7108
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1215.4344
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1150.0947

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 11.5098715, -15.562136 ,  -9.480399 ,   2.82139  ,   2.4180126],
#         [  5.2922535,   3.8604817,  -9.278907 ,  11.688657 ,   8.93105  ]],
#        dtype=float32),
#  array([-3.0367465, -2.4098055,  2.5367475,  4.457103 ,  1.3087776],
#        dtype=float32)]

# %%
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[  31.2],
#        [ -55.2],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [  21.3],
#        [-120.2],
#        [  87.5],
#        [  31.2],
#        [  87.5],
#        [ -55.3],
#        [  87.5],
#        [ -53.7],
#        [-120.2],
#        [  21.3],
#        [ -53.7],
#        [ -28.5],
#        [-120.2],
#        [ -55.2],
#        [ -55.1],
#        [   7.8],
#        [ -45.7],
#        [-120.2],
#        [ -53.7],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  21.3],
#        [ -53.7],
#        [  87.5],
#        [  87.5],
#        [ -53.6],
#        [  87.5],
#        [  87.5],
#        [   5.3],
#        [-120.2],
#        [  21.3],
#        [ -53.7],
#        [  87.5],
#        [ -53.7],
#        [  31.2],
#        [ -28.5],
#        [-120.2],
#        [  31.2],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  31.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  -7.4],
#        [-120.2],
#        [ -55.2],
#        [-120.2],
#        [-120.2],
#        [  21.3],
#        [-120.2],
#        [-120.2],
#        [   5.6],
#        [-120.2],
#        [ -53.7],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  84.9],
#        [ -28.5],
#        [   5.5],
#        [   5.4],
#        [-120.2],
#        [  31. ],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  32.6],
#        [-120.2],
#        [  87.5],
#        [ -55.7],
#        [  10.7],
#        [ -53.7],
#        [ -56.5],
#        [-120.2],
#        [ -55.2],
#        [ -53.7],
#        [ -28. ],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [  31.2],
#        [  21.3],
#        [  87.5],
#        [-120.2],
#        [ -36.2],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [ -55.2],
#        [  65.6],
#        [  31.2],
#        [  21.3],
#        [-120.2],
#        [-120.2],
#        [  30.9],
#        [  21.3],
#        [  87.5],
#        [   5.3],
#        [ -53.8],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [  76.6],
#        [  87.5],
#        [-120.2],
#        [  87.5],
#        [ -55.2],
#        [ -93.7],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [ -59.2],
#        [-120.2],
#        [ -54.9],
#        [   5.3],
#        [  87.5],
#        [  18.3],
#        [ -72.3],
#        [-120.2],
#        [-120.2],
#        [  31.2],
#        [  87.5],
#        [  31.2],
#        [-120.2],
#        [ -55.2],
#        [ -39.8],
#        [  19. ],
#        [  14.1],
#        [ -55.3],
#        [ -11.9],
#        [  87.5],
#        [ -55.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [  21.3],
#        [  87.5],
#        [  21.3],
#        [  87.5],
#        [-120.2],
#        [ -55.2],
#        [  87.1],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [  45.3],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [ -72.1],
#        [  10.9],
#        [  87.5],
#        [  21.3],
#        [   7.8],
#        [  30.1],
#        [  87.5],
#        [ -90.4],
#        [ -56. ],
#        [  87.4],
#        [  31.2],
#        [-120.2],
#        [  21.3],
#        [-120.2],
#        [ -28.5],
#        [  87.5],
#        [-120.2],
#        [ -55.2],
#        [-120.2],
#        [  87.5],
#        [   5.3],
#        [ -20.6],
#        [  87.2],
#        [   5.4],
#        [ -52.5],
#        [-120.2],
#        [ -53.7],
#        [-120.2],
#        [ -53.7],
#        [   5.3],
#        [  31.2],
#        [  21.3],
#        [-120.2],
#        [-120.2],
#        [ -55.2],
#        [   5.3],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [   5.3],
#        [-120.2],
#        [   5.3],
#        [ -53.7],
#        [  21.3],
#        [ -55. ],
#        [   4.8],
#        [ -53.8],
#        [   5.3],
#        [-120.1],
#        [  87.5],
#        [  21.3],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [ -55.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [ -53.7],
#        [-120.2],
#        [  21.3],
#        [   5.7],
#        [ -46.8],
#        [ -55.2],
#        [ -53.7],
#        [  87.5],
#        [  45.6],
#        [  21.3],
#        [ -55.2],
#        [  14.2],
#        [-120.2],
#        [-120.2],
#        [   5.3],
#        [  87.5],
#        [   5.6],
#        [  87.5],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [  87.5],
#        [ -28.5],
#        [  87.5],
#        [-120.2],
#        [-120.1],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [ -28.4],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [  84.2],
#        [  87.5],
#        [ -50.8],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [ -28.5],
#        [  87.5],
#        [ -53.7],
#        [   5.3],
#        [  31.2],
#        [-120.2],
#        [  21.3],
#        [  55.9],
#        [ -55.2],
#        [ -55.2],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [ -28.5],
#        [ -28.5],
#        [-120.2],
#        [  87.5],
#        [ -28.5],
#        [  87.5],
#        [  87.5],
#        [   5.3],
#        [  21.5],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [ -54.3],
#        [ -52.6],
#        [  19.9],
#        [ -52.3],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [-120.2],
#        [ -55.2],
#        [-120.2],
#        [ -55.2],
#        [  87.5],
#        [  35.4],
#        [ -55.2],
#        [   6.4],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [ -53.9],
#        [  87.5],
#        [-120.2],
#        [ -53.7],
#        [ -53.9],
#        [  31.2],
#        [ -41.8],
#        [ -53.7],
#        [   5.3],
#        [  87.5],
#        [ -30.2],
#        [  87.5],
#        [-120.2],
#        [  21.5],
#        [  21.3],
#        [-120.2],
#        [  87.5],
#        [ -53.7],
#        [-120.2],
#        [  87.5],
#        [ -55.6],
#        [   5.3],
#        [  87.4],
#        [  87.5],
#        [ -77.3],
#        [ -55.2],
#        [-120.2],
#        [ -55.2],
#        [   5.3],
#        [ -53.7],
#        [ -55.2],
#        [-120.2],
#        [-120.2],
#        [  21.3],
#        [-120.2],
#        [-120.2],
#        [   5.3],
#        [  21.3],
#        [-120.2],
#        [ -45.5],
#        [   5.3],
#        [  21.3],
#        [ -55.2],
#        [-120.1],
#        [-120.2],
#        [  87.5],
#        [ -28.7],
#        [  87.5],
#        [ -48.8],
#        [  87.5],
#        [-120.2],
#        [  87.5],
#        [ -55.2],
#        [-120.2],
#        [  21.3],
#        [  29.2],
#        [  32.1],
#        [-120.2],
#        [-120.2],
#        [  21.3],
#        [ -55.2],
#        [  22.7],
#        [  26.1],
#        [ -55.2],
#        [ -27.8],
#        [  87.5],
#        [-120.2],
#        [  31.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [  87.5],
#        [ -53.7],
#        [-120.2],
#        [ -55.2],
#        [  87.4],
#        [  87.5],
#        [  87.5],
#        [ -55.3],
#        [-120.2],
#        [  18.8],
#        [  31.2],
#        [ -55.6],
#        [ -53.7],
#        [ -55.2],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [ -27.2],
#        [  86.2],
#        [  87.5],
#        [ -53.6],
#        [-120.2],
#        [  24.9],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [ -55.2],
#        [-120.2],
#        [ -53.7],
#        [-120.2],
#        [  31.2],
#        [  87.5],
#        [ -77. ],
#        [ -55.1],
#        [-120.2],
#        [  31.2],
#        [ -55.2],
#        [ -51.3],
#        [   5.3],
#        [ -53.7],
#        [ -53.7],
#        [  87.5],
#        [ -45.8],
#        [-120.2],
#        [  87.5],
#        [  31.1],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [ -53.7],
#        [-120.2],
#        [ -53.8],
#        [  87.5],
#        [  23.2],
#        [   5.3],
#        [ -53.7],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [  87.4],
#        [   5.3],
#        [  86.4],
#        [ -53.8],
#        [   5.3],
#        [-120.2],
#        [ -55.1],
#        [  83. ],
#        [-120.2],
#        [ -54.8],
#        [   5.3],
#        [-120.2],
#        [  16.9],
#        [ -53.7],
#        [ -53.7],
#        [   5.3],
#        [   5.1],
#        [ -55.2],
#        [  21.3],
#        [   5.3],
#        [ -53.7],
#        [  21.3],
#        [  31.2],
#        [  87.5],
#        [-120.2],
#        [ -55.2],
#        [  87.5],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [  87.5],
#        [ -28.6],
#        [ -28.5],
#        [  11.4],
#        [  21.3],
#        [-120.2],
#        [ -55.1],
#        [  87.5],
#        [ -28.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [   5.4],
#        [   5.2],
#        [  87.5],
#        [  87.5],
#        [   5.3],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [  87.1],
#        [  21.6],
#        [  69.4],
#        [  87.5],
#        [ -28.1],
#        [ -53.7],
#        [  21.3],
#        [  87.5],
#        [  31.2],
#        [  87.5],
#        [ -28.5],
#        [  31.2],
#        [ -54.7],
#        [ -55.2],
#        [ -55.2],
#        [ -53.7],
#        [ -55.2],
#        [ -55.2],
#        [   5.3],
#        [  31.1],
#        [ -55.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [ -53.7],
#        [-120.2],
#        [-120.2],
#        [ -53.7],
#        [  87.5],
#        [ -53.7],
#        [  87.5],
#        [   5.3],
#        [-120.2],
#        [  15.3],
#        [ -64.6],
#        [  21.3],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [-120.1],
#        [ -77. ],
#        [ -55.2],
#        [  87.4],
#        [ -28.5],
#        [  22.4],
#        [  87.5],
#        [  87.5],
#        [  21.3],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [   5.2],
#        [-120.2],
#        [  87.5],
#        [ -55.2],
#        [-120.2],
#        [   5.5],
#        [-120.2],
#        [-120.2],
#        [  21.3],
#        [   5.3],
#        [ -87.5],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [ -53.7],
#        [-120.2],
#        [-120.2],
#        [ -53.7],
#        [-120.2],
#        [ -53.7],
#        [  -7.8],
#        [   5.3],
#        [ -55.2],
#        [ -53.7],
#        [  31.2],
#        [  87.5],
#        [-120.2],
#        [ -55.3],
#        [-120.2],
#        [ -55.2],
#        [ -26.3],
#        [-120.2],
#        [-120.2],
#        [ -55.2],
#        [  87. ],
#        [ -53.7],
#        [ -55.2],
#        [  87.5],
#        [-120.2],
#        [ -53.7],
#        [ -39.7],
#        [ -95.5],
#        [  87.5],
#        [ -53.7],
#        [ -53.7],
#        [  87.1],
#        [  87.5],
#        [ -53.7],
#        [  87.5],
#        [  21.3],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [ -55. ],
#        [   5.3],
#        [ -55.2],
#        [   5.3],
#        [  87.5],
#        [  -2.7],
#        [ -55.3],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [ -28.5],
#        [  87.5],
#        [  87.5],
#        [ -28.5],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [ -28.2],
#        [  87.5],
#        [ -53.8],
#        [  31.2],
#        [-120.2],
#        [-120.2],
#        [-120.1],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  11.6],
#        [   5.6],
#        [ -28.5],
#        [  80.6],
#        [  87.5],
#        [  87.5],
#        [  87.5],
#        [ -28.4],
#        [  21.3],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [ -55.2],
#        [ -55.2],
#        [  87.5],
#        [ -66.3],
#        [  31.2],
#        [ -55.2],
#        [  87.5],
#        [   5.5],
#        [  34. ],
#        [  87.5],
#        [-120.2],
#        [ -28.6],
#        [-120.2],
#        [ -28.5],
#        [ -53.7],
#        [ -28.8],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [   5.3],
#        [  87.5],
#        [ -53.7],
#        [-120.2],
#        [  87.5],
#        [ -55.2],
#        [-120.1],
#        [ -28.5],
#        [ -53.7],
#        [  87.5],
#        [  73.1],
#        [-120.2],
#        [ -28.5],
#        [-120.2],
#        [ -28.5],
#        [ -55.2],
#        [  87.1],
#        [  87.5],
#        [  31.2],
#        [  87.4],
#        [-120.2],
#        [-120.2],
#        [ -57.6],
#        [ -28.5],
#        [   5.7],
#        [  31.1],
#        [  21.3],
#        [  21.3],
#        [ -28.5],
#        [  21.3],
#        [  30.9],
#        [  31.2],
#        [  24.6],
#        [ -55.2],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [  19.9],
#        [ -55.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [ -53.7],
#        [  87.5],
#        [-120.2],
#        [ -53.8],
#        [  21.3],
#        [-120.2],
#        [  36.7],
#        [  87.5],
#        [  87.5],
#        [  31.2],
#        [-120.2],
#        [-120.2],
#        [  31.2],
#        [-120.2],
#        [-120.2],
#        [  30.6],
#        [  31.2],
#        [   5.3],
#        [ -28.5],
#        [-120.2],
#        [  37.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [ -53.8],
#        [  87.5],
#        [-120.2],
#        [   5.2],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [  45.6],
#        [  87.5],
#        [   5.3],
#        [  86.8],
#        [-120.2],
#        [-120.2],
#        [-120.2],
#        [  21.3],
#        [ -53.7],
#        [  87.5],
#        [  21.3],
#        [  31.2],
#        [  21.3],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [ -55.2],
#        [  87.4],
#        [ -55.2],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [ -53.7],
#        [ -78.8],
#        [-119.9],
#        [  21.3],
#        [  31.2],
#        [  87.5],
#        [ -53.7],
#        [   5.3],
#        [   5.3],
#        [  58.5],
#        [ -28.5],
#        [ -75.2],
#        [  87.5],
#        [ -55.4],
#        [  31.2],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [   5.3],
#        [ -53.7],
#        [  31.2],
#        [  21.3],
#        [-120.2],
#        [ -53.7],
#        [ -27.3],
#        [   5.3],
#        [  18. ],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [   5.3],
#        [-120.2],
#        [ -53.7],
#        [  87.4],
#        [   5.3],
#        [  12.3],
#        [-120.2],
#        [  87.5],
#        [  30.9],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [ -29. ],
#        [  87.5],
#        [ -55.2],
#        [ -28.5],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [ -28.6],
#        [-120.2],
#        [  21.3],
#        [-116.8],
#        [-120.2],
#        [  87.5],
#        [   4.8],
#        [  31.2],
#        [  24.1],
#        [ -28.5],
#        [-120.2],
#        [  31.1],
#        [ -55.7],
#        [-120.2],
#        [  87.5],
#        [ -55.2],
#        [   5.4],
#        [  87.5],
#        [  21.3],
#        [  50.1],
#        [   5.3],
#        [  87.5],
#        [-120.2],
#        [ -33.2],
#        [   5.9],
#        [  21.3],
#        [-120.2],
#        [-105.8],
#        [ -53.7],
#        [  87.5],
#        [ -74.9],
#        [  87.5],
#        [ -28.5],
#        [  87.4],
#        [  87.4],
#        [  31.2],
#        [  87.5],
#        [  87.5],
#        [  31.2],
#        [  87.5],
#        [  87.5],
#        [ -53.7],
#        [  20.5],
#        [ -53.7],
#        [ -55.2],
#        [ -55.5],
#        [-120.2],
#        [ -55.2],
#        [-119.5],
#        [ -28.5],
#        [-120.2],
#        [ -55.8],
#        [  87.5],
#        [-120.2],
#        [  21.3],
#        [-120.2],
#        [ -80.6],
#        [  14.8],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [  31.2],
#        [   5.7],
#        [-120.2],
#        [   5.4],
#        [ -28.5],
#        [  87.5],
#        [  21.3],
#        [  32.5],
#        [ -55.2],
#        [  87.5],
#        [  25.1],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  87.5],
#        [ -51. ],
#        [  31.2],
#        [-120.2],
#        [  21.3],
#        [   5.4],
#        [-120.2],
#        [ -55.2],
#        [ -28.5],
#        [  21.1],
#        [  87.5],
#        [  21.3],
#        [   5.3],
#        [ -55.2],
#        [ -55.8],
#        [-120.2],
#        [  21.3],
#        [  87.5],
#        [   5.3],
#        [  21.3],
#        [ -55.4],
#        [  31.2],
#        [ -28.5],
#        [ -55.2],
#        [-120.2],
#        [-120.2],
#        [  30.4],
#        [  87.5],
#        [   5.3],
#        [ -56. ],
#        [ -54. ],
#        [-120.2],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [ -62.5],
#        [   5.3],
#        [  87.5],
#        [ -54.3],
#        [ -53.7],
#        [  36.2],
#        [-120.2],
#        [  31.2],
#        [ -53.9],
#        [-120.2],
#        [ -67.1],
#        [-120.2],
#        [ -72.3],
#        [   4.5],
#        [ -55.1],
#        [  87.5],
#        [  87.5],
#        [-120.2],
#        [-120.2],
#        [  87.5],
#        [  21.3],
#        [   3.6],
#        [  87.5],
#        [ -75.7],
#        [  87.5],
#        [ -55.2],
#        [  87.5],
#        [  87.5],
#        [  11.9],
#        [-120.2],
#        [  31.2],
#        [ -55.2],
#        [ -55.2],
#        [-120. ],
#        [  87.5],
#        [ -55.2],
#        [  87.5],
#        [  87.5],
#        [ -28.5],
#        [  87.5],
#        [-120.2],
#        [  87.4]], dtype=float32)

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])),
         np.squeeze(training_data['targets']), color='orange')
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
